# %%
# !pip install diffusers transformers accelerate datasets safetensors peft
# Out:
# Requirement already satisfied: diffusers in /home/rguktongole/anaconda3/lib/python3.12/site-packages (0.32.2)
# Requirement already satisfied: transformers in /home/rguktongole/anaconda3/lib/python3.12/site-packages (4.49.0)
# Requirement already satisfied: accelerate in /home/rguktongole/anaconda3/lib/python3.12/site-packages (1.5.0)
# Requirement already satisfied: datasets in /home/rguktongole/anaconda3/lib/python3.12/site-packages (3.6.0)
# Requirement already satisfied: safetensors in /home/rguktongole/anaconda3/lib/python3.12/site-packages (0.5.3)
# Requirement already satisfied: peft in /home/rguktongole/anaconda3/lib/python3.12/site-packages (0.15.2)
# Requirement already satisfied: importlib-metadata in /home/rguktongole/anaconda3/lib/python3.12/site-packages (from diffusers) (7.0.1)
# Requirement already satisfied: filelock in /home/rguktongole/anaconda3/lib/python3.12/site-packages (from diffusers) (3.13.1)
# Requirement already satisfied: huggingface-hub>=0.23.2 in /home/rguktongole/anaconda3/lib/python3.12/site-packages (from diffusers) (0.29.2)
# Requirement already satisfied: numpy in /home/rguktongole/anaconda3/lib/python3.12/site-packages (from diffusers) (1.26.4)
# Requirement already satisfied: regex!=2019.12.17 in /home/rguktongole/anaconda3/lib/python3.12/site-packages (from diffusers) (2024.9.11)
# Requirement already satisfied: requests in /home/rguktongole/anaconda3/lib/python3.12/site-packages (from diffusers) (2.32.3)
# Requirement already satisfied: Pillow in /home/rguktongole/anaconda3/lib/python3.12/site-packages (from diffusers) (10.4.0)
# Requirement already satisfied: packaging>=20.0 in /home/rguktongole/anaconda3/lib/python3.12/site-packages (from transformers) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in /home/rguktongole/anaconda3/lib/python3.12/site-packages (from transformers) (6.0.1)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /home/rguktongole/anaconda3/lib/python3.12/site-packages (from transformers) (0.21.0)
# Requirement already satisfied: tqdm>=4.27 in /home/rguktongole/anaconda3/lib/python3.12/site-packages (from transformers) (4.66.5)
# Requirement already satisfied: fsspec>=2023.5.0 in /home/rguktongole/anaconda3/lib/python3.12/site-packages (from huggingface-hub>=0.23.2->diffusers) (2024.6.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /home/rguktongole/anaconda3/lib/python3.12/site-packages (from huggingface-hub>=0.23.2->diffusers) (4.11.0)
# Requirement already satisfied: psutil in /home/rguktongole/.local/lib/python3.12/site-packages (from accelerate) (6.0.0)
# Requirement already satisfied: torch>=2.0.0 in /home/rguktongole/anaconda3/lib/python3.12/site-packages (from accelerate) (2.6.0)
# Requirement already satisfied: pyarrow>=15.0.0 in /home/rguktongole/anaconda3/lib/python3.12/site-packages (from datasets) (16.1.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /home/rguktongole/anaconda3/lib/python3.12/site-packages (from datasets) (0.3.8)
# Requirement already satisfied: pandas in /home/rguktongole/anaconda3/lib/python3.12/site-packages (from datasets) (2.2.2)
# Requirement already satisfied: xxhash in /home/rguktongole/anaconda3/lib/python3.12/site-packages (from datasets) (3.5.0)
# Requirement already satisfied: multiprocess<0.70.17 in /home/rguktongole/anaconda3/lib/python3.12/site-packages (from datasets) (0.70.16)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /home/rguktongole/anaconda3/lib/python3.12/site-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (3.10.5)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /home/rguktongole/anaconda3/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (2.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /home/rguktongole/anaconda3/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (1.2.0)
# Requirement already satisfied: attrs>=17.3.0 in /home/rguktongole/anaconda3/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (23.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/rguktongole/anaconda3/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (1.4.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/rguktongole/anaconda3/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in /home/rguktongole/anaconda3/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (1.11.0)
# Requirement already satisfied: idna>=2.0 in /home/rguktongole/anaconda3/lib/python3.12/site-packages (from yarl<2.0,>=1.0->aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (3.7)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/rguktongole/anaconda3/lib/python3.12/site-packages (from requests->diffusers) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/rguktongole/anaconda3/lib/python3.12/site-packages (from requests->diffusers) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /home/rguktongole/anaconda3/lib/python3.12/site-packages (from requests->diffusers) (2025.1.31)
# Requirement already satisfied: networkx in /home/rguktongole/anaconda3/lib/python3.12/site-packages (from torch>=2.0.0->accelerate) (3.3)
# Requirement already satisfied: jinja2 in /home/rguktongole/anaconda3/lib/python3.12/site-packages (from torch>=2.0.0->accelerate) (3.1.4)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /home/rguktongole/anaconda3/lib/python3.12/site-packages (from torch>=2.0.0->accelerate) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /home/rguktongole/anaconda3/lib/python3.12/site-packages (from torch>=2.0.0->accelerate) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /home/rguktongole/anaconda3/lib/python3.12/site-packages (from torch>=2.0.0->accelerate) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /home/rguktongole/anaconda3/lib/python3.12/site-packages (from torch>=2.0.0->accelerate) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /home/rguktongole/anaconda3/lib/python3.12/site-packages (from torch>=2.0.0->accelerate) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /home/rguktongole/anaconda3/lib/python3.12/site-packages (from torch>=2.0.0->accelerate) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /home/rguktongole/anaconda3/lib/python3.12/site-packages (from torch>=2.0.0->accelerate) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /home/rguktongole/anaconda3/lib/python3.12/site-packages (from torch>=2.0.0->accelerate) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /home/rguktongole/anaconda3/lib/python3.12/site-packages (from torch>=2.0.0->accelerate) (12.3.1.170)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /home/rguktongole/anaconda3/lib/python3.12/site-packages (from torch>=2.0.0->accelerate) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /home/rguktongole/anaconda3/lib/python3.12/site-packages (from torch>=2.0.0->accelerate) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /home/rguktongole/anaconda3/lib/python3.12/site-packages (from torch>=2.0.0->accelerate) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /home/rguktongole/anaconda3/lib/python3.12/site-packages (from torch>=2.0.0->accelerate) (12.4.127)
# Requirement already satisfied: triton==3.2.0 in /home/rguktongole/anaconda3/lib/python3.12/site-packages (from torch>=2.0.0->accelerate) (3.2.0)
# Requirement already satisfied: setuptools in /home/rguktongole/anaconda3/lib/python3.12/site-packages (from torch>=2.0.0->accelerate) (75.1.0)
# Requirement already satisfied: sympy==1.13.1 in /home/rguktongole/anaconda3/lib/python3.12/site-packages (from torch>=2.0.0->accelerate) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/rguktongole/anaconda3/lib/python3.12/site-packages (from sympy==1.13.1->torch>=2.0.0->accelerate) (1.3.0)
# Requirement already satisfied: zipp>=0.5 in /home/rguktongole/anaconda3/lib/python3.12/site-packages (from importlib-metadata->diffusers) (3.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/rguktongole/anaconda3/lib/python3.12/site-packages (from jinja2->torch>=2.0.0->accelerate) (2.1.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/rguktongole/.local/lib/python3.12/site-packages (from pandas->datasets) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/rguktongole/anaconda3/lib/python3.12/site-packages (from pandas->datasets) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /home/rguktongole/anaconda3/lib/python3.12/site-packages (from pandas->datasets) (2023.3)
# Requirement already satisfied: six>=1.5 in /home/rguktongole/.local/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.16.0)

# %%
# !pip install -U peft
# Out:
# Requirement already satisfied: peft in /home/rguktongole/anaconda3/lib/python3.12/site-packages (0.15.2)
# Requirement already satisfied: numpy>=1.17 in /home/rguktongole/anaconda3/lib/python3.12/site-packages (from peft) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /home/rguktongole/anaconda3/lib/python3.12/site-packages (from peft) (24.1)
# Requirement already satisfied: psutil in /home/rguktongole/.local/lib/python3.12/site-packages (from peft) (6.0.0)
# Requirement already satisfied: pyyaml in /home/rguktongole/anaconda3/lib/python3.12/site-packages (from peft) (6.0.1)
# Requirement already satisfied: torch>=1.13.0 in /home/rguktongole/anaconda3/lib/python3.12/site-packages (from peft) (2.6.0)
# Requirement already satisfied: transformers in /home/rguktongole/anaconda3/lib/python3.12/site-packages (from peft) (4.49.0)
# Requirement already satisfied: tqdm in /home/rguktongole/anaconda3/lib/python3.12/site-packages (from peft) (4.66.5)
# Requirement already satisfied: accelerate>=0.21.0 in /home/rguktongole/anaconda3/lib/python3.12/site-packages (from peft) (1.5.0)
# Requirement already satisfied: safetensors in /home/rguktongole/anaconda3/lib/python3.12/site-packages (from peft) (0.5.3)
# Requirement already satisfied: huggingface_hub>=0.25.0 in /home/rguktongole/anaconda3/lib/python3.12/site-packages (from peft) (0.29.2)
# Requirement already satisfied: filelock in /home/rguktongole/anaconda3/lib/python3.12/site-packages (from huggingface_hub>=0.25.0->peft) (3.13.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /home/rguktongole/anaconda3/lib/python3.12/site-packages (from huggingface_hub>=0.25.0->peft) (2024.6.1)
# Requirement already satisfied: requests in /home/rguktongole/anaconda3/lib/python3.12/site-packages (from huggingface_hub>=0.25.0->peft) (2.32.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /home/rguktongole/anaconda3/lib/python3.12/site-packages (from huggingface_hub>=0.25.0->peft) (4.11.0)
# Requirement already satisfied: networkx in /home/rguktongole/anaconda3/lib/python3.12/site-packages (from torch>=1.13.0->peft) (3.3)
# Requirement already satisfied: jinja2 in /home/rguktongole/anaconda3/lib/python3.12/site-packages (from torch>=1.13.0->peft) (3.1.4)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /home/rguktongole/anaconda3/lib/python3.12/site-packages (from torch>=1.13.0->peft) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /home/rguktongole/anaconda3/lib/python3.12/site-packages (from torch>=1.13.0->peft) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /home/rguktongole/anaconda3/lib/python3.12/site-packages (from torch>=1.13.0->peft) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /home/rguktongole/anaconda3/lib/python3.12/site-packages (from torch>=1.13.0->peft) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /home/rguktongole/anaconda3/lib/python3.12/site-packages (from torch>=1.13.0->peft) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /home/rguktongole/anaconda3/lib/python3.12/site-packages (from torch>=1.13.0->peft) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /home/rguktongole/anaconda3/lib/python3.12/site-packages (from torch>=1.13.0->peft) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /home/rguktongole/anaconda3/lib/python3.12/site-packages (from torch>=1.13.0->peft) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /home/rguktongole/anaconda3/lib/python3.12/site-packages (from torch>=1.13.0->peft) (12.3.1.170)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /home/rguktongole/anaconda3/lib/python3.12/site-packages (from torch>=1.13.0->peft) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /home/rguktongole/anaconda3/lib/python3.12/site-packages (from torch>=1.13.0->peft) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /home/rguktongole/anaconda3/lib/python3.12/site-packages (from torch>=1.13.0->peft) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /home/rguktongole/anaconda3/lib/python3.12/site-packages (from torch>=1.13.0->peft) (12.4.127)
# Requirement already satisfied: triton==3.2.0 in /home/rguktongole/anaconda3/lib/python3.12/site-packages (from torch>=1.13.0->peft) (3.2.0)
# Requirement already satisfied: setuptools in /home/rguktongole/anaconda3/lib/python3.12/site-packages (from torch>=1.13.0->peft) (75.1.0)
# Requirement already satisfied: sympy==1.13.1 in /home/rguktongole/anaconda3/lib/python3.12/site-packages (from torch>=1.13.0->peft) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/rguktongole/anaconda3/lib/python3.12/site-packages (from sympy==1.13.1->torch>=1.13.0->peft) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/rguktongole/anaconda3/lib/python3.12/site-packages (from jinja2->torch>=1.13.0->peft) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/rguktongole/anaconda3/lib/python3.12/site-packages (from requests->huggingface_hub>=0.25.0->peft) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/rguktongole/anaconda3/lib/python3.12/site-packages (from requests->huggingface_hub>=0.25.0->peft) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/rguktongole/anaconda3/lib/python3.12/site-packages (from requests->huggingface_hub>=0.25.0->peft) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /home/rguktongole/anaconda3/lib/python3.12/site-packages (from requests->huggingface_hub>=0.25.0->peft) (2025.1.31)
# Requirement already satisfied: regex!=2019.12.17 in /home/rguktongole/anaconda3/lib/python3.12/site-packages (from transformers->peft) (2024.9.11)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /home/rguktongole/anaconda3/lib/python3.12/site-packages (from transformers->peft) (0.21.0)

# %%
from huggingface_hub import login
login("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")

# %%
import os
import json
import torch
from PIL import Image
from torchvision import transforms
from datasets import Dataset
from tqdm import tqdm
from diffusers import StableDiffusionPipeline
from peft import get_peft_model, LoraConfig, TaskType

# ---------------------
# Config
# ---------------------
model_id = "runwayml/stable-diffusion-v1-5"
data_dir = "/home/rguktongole/LIFE/NULLCLASS/TASK5/flowers"
images_dir = os.path.join(data_dir, "images")
captions_file = os.path.join(data_dir, "captions_blip.json")
output_dir = "home/rguktongole/LIFE/NULLCLASS/TASK5/lora-finetuned-flower"

# ---------------------
# Load and Prepare Dataset
# ---------------------
with open(captions_file, "r") as f:
    caption_data = json.load(f)

dataset_entries = []
for item in caption_data:
    if isinstance(item, dict) and "image" in item and "text" in item:
        image_path = os.path.join(images_dir, item["image"])
        if os.path.exists(image_path):
            dataset_entries.append({
                "image_path": image_path,
                "caption": item["text"]
            })

dataset = Dataset.from_list(dataset_entries)

def preprocess(example):
    image = Image.open(example["image_path"]).convert("RGB").resize((512, 512))
    transform = transforms.ToTensor()
    example["pixel_values"] = transform(image)
    return example

dataset = dataset.map(preprocess)

# ---------------------
# Load Stable Diffusion
# ---------------------
pipe = StableDiffusionPipeline.from_pretrained(
    model_id,
    torch_dtype=torch.float16
).to("cuda")

# ---------------------
# Apply LoRA with Fallback
# ---------------------
try:
    lora_config = LoraConfig(
        r=4,
        lora_alpha=16,
        target_modules=["to_q", "to_k", "to_v", "to_out.0"],
        lora_dropout=0.1,
        bias="none",
        task_type=TaskType.UNET  # Preferred if available
    )
except AttributeError:
    print("⚠️ Warning: TaskType.UNET not found, using TaskType.FEATURE_EXTRACTION instead.")
    lora_config = LoraConfig(
        r=4,
        lora_alpha=16,
        target_modules=["to_q", "to_k", "to_v", "to_out.0"],
        lora_dropout=0.1,
        bias="none",
        task_type=TaskType.FEATURE_EXTRACTION
    )

pipe.unet = get_peft_model(pipe.unet, lora_config)

# ---------------------
# Optimizer
# ---------------------
optimizer = torch.optim.AdamW(pipe.unet.parameters(), lr=1e-5)

# ---------------------
# Training Loop
# ---------------------
for epoch in range(3):  # You can adjust this
    for i in tqdm(range(len(dataset))):
        sample = dataset[i]

        inputs = pipe.tokenizer(
            sample["caption"],
            return_tensors="pt",
            padding="max_length",
            truncation=True,
            max_length=77
        ).to("cuda")

        image_tensor = sample["pixel_values"].unsqueeze(0).to("cuda")
        with torch.no_grad():
            latents = pipe.vae.encode(image_tensor).latent_dist.sample()

        noise = torch.randn_like(latents)
        timesteps = torch.randint(0, 1000, (1,), device="cuda").long()
        noisy_latents = pipe.scheduler.add_noise(latents, noise, timesteps)

        with torch.no_grad():
            encoder_hidden_states = pipe.text_encoder(**inputs).last_hidden_state

        model_pred = pipe.unet(noisy_latents, timesteps, encoder_hidden_states).sample

        loss = torch.nn.functional.mse_loss(model_pred, noise)
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        if i % 50 == 0:
            print(f"Epoch {epoch}, Step {i}, Loss: {loss.item():.4f}")

# ---------------------
# Save Fine-Tuned Model
# ---------------------
pipe.unet.save_pretrained(output_dir)
pipe.save_pretrained(output_dir)
print(f"✅ Model saved at {output_dir}")
# Out:
# 2025-05-13 18:17:45.783641: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1747140466.811461    5142 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1747140467.019390    5142 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1747140469.125898    5142 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1747140469.125981    5142 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1747140469.125987    5142 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1747140469.125992    5142 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2025-05-13 18:17:49.333409: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Loading pipeline components...:   0%|          | 0/7 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[2], line 52
#      44 dataset = dataset.map(preprocess)
#      46 # ---------------------
#      47 # Load Stable Diffusion
#      48 # ---------------------
#      49 pipe = StableDiffusionPipeline.from_pretrained(
#      50     model_id,
#      51     torch_dtype=torch.float16
# ---> 52 ).to("cuda")
#      54 # ---------------------
#      55 # Apply LoRA with Fallback
#      56 # ---------------------
#      57 try:
#
# File ~/anaconda3/lib/python3.12/site-packages/diffusers/pipelines/pipeline_utils.py:461, in DiffusionPipeline.to(self, *args, **kwargs)
#     459     module.to(device=device)
#     460 elif not is_loaded_in_4bit_bnb and not is_loaded_in_8bit_bnb:
# --> 461     module.to(device, dtype)
#     463 if (
#     464     module.dtype == torch.float16
#     465     and str(device) in ["cpu"]
#     466     and not silence_dtype_warnings
#     467     and not is_offloaded
#     468 ):
#     469     logger.warning(
#     470         "Pipelines loaded with `dtype=torch.float16` cannot run with `cpu` device. It"
#     471         " is not recommended to move them to `cpu` as running them will fail. Please make"
#    (...)
#     474         " `torch_dtype=torch.float16` argument, or use another device for inference."
#     475     )
#
# File ~/anaconda3/lib/python3.12/site-packages/diffusers/models/modeling_utils.py:1077, in ModelMixin.to(self, *args, **kwargs)
#    1072     elif is_bitsandbytes_version("<", "0.43.2"):
#    1073         raise ValueError(
#    1074             "Calling `to()` is not supported for `4-bit` quantized models with the installed version of bitsandbytes. "
#    1075             f"The current device is `{self.device}`. If you intended to move the model, please install bitsandbytes >= 0.43.2."
#    1076         )
# -> 1077 return super().to(*args, **kwargs)
#
# File ~/anaconda3/lib/python3.12/site-packages/torch/nn/modules/module.py:1343, in Module.to(self, *args, **kwargs)
#    1340         else:
#    1341             raise
# -> 1343 return self._apply(convert)
#
# File ~/anaconda3/lib/python3.12/site-packages/torch/nn/modules/module.py:903, in Module._apply(self, fn, recurse)
#     901 if recurse:
#     902     for module in self.children():
# --> 903         module._apply(fn)
#     905 def compute_should_use_set_data(tensor, tensor_applied):
#     906     if torch._has_compatible_shallow_copy_type(tensor, tensor_applied):
#     907         # If the new tensor has compatible tensor type as the existing tensor,
#     908         # the current behavior is to change the tensor in-place using `.data =`,
#    (...)
#     913         # global flag to let the user control whether they want the future
#     914         # behavior of overwriting the existing tensor or not.
#
# File ~/anaconda3/lib/python3.12/site-packages/torch/nn/modules/module.py:903, in Module._apply(self, fn, recurse)
#     901 if recurse:
#     902     for module in self.children():
# --> 903         module._apply(fn)
#     905 def compute_should_use_set_data(tensor, tensor_applied):
#     906     if torch._has_compatible_shallow_copy_type(tensor, tensor_applied):
#     907         # If the new tensor has compatible tensor type as the existing tensor,
#     908         # the current behavior is to change the tensor in-place using `.data =`,
#    (...)
#     913         # global flag to let the user control whether they want the future
#     914         # behavior of overwriting the existing tensor or not.
#
# File ~/anaconda3/lib/python3.12/site-packages/torch/nn/modules/module.py:930, in Module._apply(self, fn, recurse)
#     926 # Tensors stored in modules are graph leaves, and we don't want to
#     927 # track autograd history of `param_applied`, so we have to use
#     928 # `with torch.no_grad():`
#     929 with torch.no_grad():
# --> 930     param_applied = fn(param)
#     931 p_should_use_set_data = compute_should_use_set_data(param, param_applied)
#     933 # subclasses may have multiple child tensors so we need to use swap_tensors
#
# File ~/anaconda3/lib/python3.12/site-packages/torch/nn/modules/module.py:1329, in Module.to.<locals>.convert(t)
#    1322     if convert_to_format is not None and t.dim() in (4, 5):
#    1323         return t.to(
#    1324             device,
#    1325             dtype if t.is_floating_point() or t.is_complex() else None,
#    1326             non_blocking,
#    1327             memory_format=convert_to_format,
#    1328         )
# -> 1329     return t.to(
#    1330         device,
#    1331         dtype if t.is_floating_point() or t.is_complex() else None,
#    1332         non_blocking,
#    1333     )
#    1334 except NotImplementedError as e:
#    1335     if str(e) == "Cannot copy out of meta tensor; no data!":
#
# File ~/anaconda3/lib/python3.12/site-packages/torch/cuda/__init__.py:319, in _lazy_init()
#     317 if "CUDA_MODULE_LOADING" not in os.environ:
#     318     os.environ["CUDA_MODULE_LOADING"] = "LAZY"
# --> 319 torch._C._cuda_init()
#     320 # Some of the queued calls may reentrantly call _lazy_init();
#     321 # we need to just return without initializing in that case.
#     322 # However, we must not let any *other* threads in!
#     323 _tls.is_initializing = True
#
# RuntimeError: Found no NVIDIA driver on your system. Please check that you have an NVIDIA GPU and installed a driver from http://www.nvidia.com/Download/index.aspx

# %%
# Save full pipeline components manually
pipe.unet.save_pretrained(os.path.join(output_dir, "unet"))
pipe.vae.save_pretrained(os.path.join(output_dir, "vae"))
pipe.text_encoder.save_pretrained(os.path.join(output_dir, "text_encoder"))
pipe.tokenizer.save_pretrained(os.path.join(output_dir, "tokenizer"))
pipe.scheduler.save_pretrained(os.path.join(output_dir, "scheduler"))
pipe.feature_extractor.save_pretrained(os.path.join(output_dir, "feature_extractor"))
pipe.safety_checker.save_pretrained(os.path.join(output_dir, "safety_checker"))
print(f"✅ All components saved to {output_dir}")

# %%
from diffusers import StableDiffusionPipeline
import torch

pipe = StableDiffusionPipeline.from_pretrained(
    "./lora-finetuned-flower",  # contains subfolders like "unet", "vae", etc.
    torch_dtype=torch.float16
).to("cuda")

prompt = "A watercolor painting of pink roses blooming in a garden"
image = pipe(prompt).images[0]
image.show()
